# %% [markdown]
# ## Smart Light Controller

# %%
class smartlight:
    def __init__(self,light_name):
        self.light_name=light_name
        self.status="OFF"
    def turn_on(self):
        self.status="ON"
    def turn_off(self):
        self.status="OFF"
    def display_status(self):
        print(f"{self.light_name} is {self.status}")
light=smartlight("Bedroom Light")
light.turn_on()
light.display_status()
light.turn_off()
light.display_status()
# Out:
# Bedroom Light is ON
# Bedroom Light is OFF

# %% [markdown]
# ## Employee ID Card System

# %%
class Employee:
    def __init__(self,name,emp_id,department):
        self.name=name
        self.emp_id=emp_id
        self.department=department
    def display_card(self):
        print("Employee ID Card")
        print(f"Name: {self.name}")
        print(f"ID: {self.emp_id}")
        print(f"Department: {self.department}")
employee=Employee("Rahul","EMP102","IT")
employee.display_card()
# Out:
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %% [markdown]
# ## Mobile Contact Record

# %%
class Contact:
    def __init__(self,name,phone):
        self.name=name
        self.phone=phone
    def display_contact(self):
        print("Contact Saved")
        print(f"Name: {self.name}")
        print(f"Phone: {self.phone}")
contact=Contact("raju","7017273872")
contact.display_contact()
# Out:
# Contact Saved
# Name: raju
# Phone: 7017273872

# %% [markdown]
# ## Product Price Tag Generator

# %%
class Product:
    def __init__(self,name,price):
        self.name=name
        self.price=price
    def display_price_tag(self):
        print(f"Product: {self.name}")
        print(f"Price: {self.price}")
product=Product("Headphones",2499)
product.display_price_tag()
# Out:
# Product: Headphones
# Price: 2499

# %% [markdown]
# ## Movie Rating Display System

# %%
class Movie:
    def __init__(self,name,rating):
        self.name=name
        self.rating=rating

    def display_movie_details(self):
        print(f"Movie: {self.name}")
        print(f"Rating:{self.rating}/5")
movie=Movie(("Inception",4.8))
movie.display_movie_details()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       7         print(f"Movie: {self.name}")
#       8         print(f"Rating:{self.rating}/5")
# ----> 9 movie=Movie(("Inception",4.8))
#      10 movie.display_movie_details()
#
# TypeError: Movie.__init__() missing 1 required positional argument: 'rating'

# %% [markdown]
# ## Delivery Address Manager

# %%
class Delivery:
    def __init__(self,customer_name,address):
        self.customer_name=customer_name
        self.address=address

    def display_delivery_details(self):
        print("Delivery Details")
        print(f"Customer: {self.customer_name}")
        print(f"Address : {self.address}")
delivery=Delivery("Suman","Hyderbad")
delivery.display_delivery_details()
# Out:
# Delivery Details
# Customer: Suman
# Address : Hyderbad
